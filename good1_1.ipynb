# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')

# %%
wls = pd.read_csv("kidneyRelatedTerms.csv",sep=".")

# %%
wordsList = list(wls[" liver"])

# %%
kw_list= []
for i in wordsList:
    kw_list.append(i.strip())

# %%
k = np.zeros(shape=(342,len(kw_list)))

# %% [markdown]
# # testing

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
pytrends.build_payload(["hello"], cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
x=pytrends.interest_by_region()
x
# Out:
#                       hello
# geoName
# Alabama                  43
# Alaska                   46
# Arizona                  60
# Arkansas                 42
# California               82
# Colorado                 53
# Connecticut              43
# Delaware                 43
# District of Columbia     66
# Florida                  58
# Georgia                  62
# Hawaii                  100
# Idaho                    39
# Illinois                 60
# Indiana                  42
# Iowa                     46
# Kansas                   47
# Kentucky                 44
# Louisiana                52
# Maine                    38
# Maryland                 49
# Massachusetts            49
# Michigan                 51
# Minnesota                50
# Mississippi              45
# Missouri                 49
# Montana                  27
# Nebraska                 43
# Nevada                   69
# New Hampshire            36
# New Jersey               50
# New Mexico               54
# New York                 56
# North Carolina           51
# North Dakota             32
# Ohio                     47
# Oklahoma                 46
# Oregon                   43
# Pennsylvania             49
# Rhode Island             47
# South Carolina           47
# South Dakota             35
# Tennessee                48
# Texas                    71
# Utah                     43
# Vermont                  38
# Virginia                 48
# Washington               56
# West Virginia            45
# Wisconsin                41
# Wyoming                  32

# %%
values = []
for s in states.values():
    if s not in x.index:
        values.append(0)
    else: values.append(int(x.loc[s].values))

# %%
values

# %% [markdown]
# # end testing

# %%
def buildDF(kword):
    k1 =[]
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    
    k1.extend(values)
    #k1 += values
    #print(k1)
   
    print("lunghezza anno2011  ",len(k1))


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    #k1 += values
    #print(k1)


    print("lunghezza anno2012   ",len(k1))

    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2013.  ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2014   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2015   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states.values():
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2016   ",len(k1))


    #print(k1)
    #for i in range(len(k1)):
    #    k1[i]= int(k1[i][0])
        #print(int(k[i][0]))
    return k1

# %%
i=0
for word in kw_list:
    k[:,i] = buildDF([word])
    i +=1

# %% [raw]
# # google

# %%
states=df_gt["LocationDesc"][2:53]

# %% [markdown]
# ## arranging data for 1.1 corr not extending for each year the query results

# %%
matrix = np.zeros(shape=(51,6))

# %%
def buildDF1(kword):
    k1 =[]
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    #print(values)
    matrix[:,0]=(values)
    #k1 += values
    #print(k1)
    print("lunghezza anno2011  ",len(k1))


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    matrix[:,1]=(values)

    #k1 += values
    #print(k1)


    print("lunghezza anno2012   ",len(k1))

    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    matrix[:,2]=(values)

    print("lunghezza anno2013.  ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    matrix[:,3]=(values)
    print("lunghezza anno2014   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    matrix[:,4]=(values)

    print("lunghezza anno2015   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    matrix[:,5]=(values)

    print("lunghezza anno2016   ",len(k1))

    


    #print(k1)
    #for i in range(len(k1)):
    #    k1[i]= int(k1[i][0])
        #print(int(k[i][0]))
    return matrix

# %%
mat=buildDF1([word])
# Out:
#  calculating indexes for  ['renal']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0

# %%
gt_Year_Type = 'data/BRFSS/2011_AA.csv'

# %%
data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
df_gt = pd.read_csv(gt_Year_Type, sep=";")
df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
df_gt = df_gt.dropna(subset=['LocationAbbr'])
data["gt"]=df_gt["Data_Value"][:-2].values
data
# Out:
#                        2011   2012   2013   2014   2015   2016   gt
# LocationDesc
# Alabama                77.0   86.0   86.0   80.0   88.0   84.0  2.5
# Alaska                 47.0   45.0   43.0   46.0   53.0   51.0  2.5
# Arizona                67.0   66.0   61.0   73.0   70.0   77.0  3.4
# Arkansas               79.0   77.0   76.0   85.0   83.0   79.0  2.8
# California             49.0   51.0   52.0   55.0   57.0   56.0  2.5
# Colorado               56.0   52.0   56.0   56.0   62.0   69.0  2.2
# Connecticut            66.0   62.0   72.0   69.0   82.0   76.0  1.8
# Delaware               58.0   81.0   72.0   84.0   86.0   80.0  2.4
# District of Columbia   51.0   51.0   59.0   56.0   54.0   59.0  2.7
# Florida                67.0   65.0   68.0   71.0   76.0   79.0  3.0
# Georgia                55.0   55.0   58.0   57.0   61.0   65.0  2.9
# Hawaii                 51.0   68.0   67.0   58.0   63.0   71.0  3.2
# Idaho                  59.0   57.0   60.0   58.0   58.0   64.0  2.4
# Illinois               61.0   60.0   61.0   62.0   61.0   63.0  2.7
# Indiana                75.0   77.0   75.0   71.0   76.0   73.0  2.0
# Iowa                   72.0   77.0   73.0   75.0   67.0   64.0  1.3
# Kansas                 65.0   61.0   61.0   59.0   55.0   68.0  2.2
# Kentucky               81.0   76.0   80.0   74.0   79.0   86.0  2.4
# Louisiana              85.0   75.0   72.0   73.0   80.0   77.0  2.5
# Maine                  62.0   66.0   65.0   70.0   77.0   74.0  2.1
# Maryland               72.0   69.0   70.0   71.0   75.0   72.0  1.8
# Massachusetts          64.0   63.0   69.0   70.0   74.0   75.0  1.8
# Michigan               70.0   65.0   70.0   70.0   73.0   72.0  2.9
# Minnesota              71.0   60.0   65.0   64.0   73.0   68.0  1.6
# Mississippi            87.0   75.0   75.0   75.0   78.0   83.0  2.3
# Missouri               76.0   71.0   72.0   71.0   80.0   79.0  2.1
# Montana                57.0   58.0   58.0   58.0   62.0   58.0  2.4
# Nebraska               82.0   64.0   72.0   77.0   68.0   65.0  2.1
# Nevada                 51.0   55.0   48.0   58.0   61.0   57.0  2.5
# New Hampshire          74.0   64.0   63.0   56.0   68.0   63.0  2.4
# New Jersey             58.0   63.0   62.0   66.0   68.0   68.0  1.9
# New Mexico             91.0   76.0   77.0   68.0   79.0   81.0  2.9
# New York               57.0   63.0   58.0   61.0   64.0   69.0  2.8
# North Carolina         66.0   63.0   66.0   62.0   65.0   65.0  2.1
# North Dakota           61.0   84.0   85.0   86.0   67.0   70.0  1.8
# Ohio                   77.0   80.0   80.0   81.0   86.0   75.0  2.3
# Oklahoma               69.0   64.0   70.0   70.0   73.0   71.0  2.9
# Oregon                 61.0   61.0   65.0   48.0   51.0   61.0  2.3
# Pennsylvania           78.0   81.0   79.0   81.0   86.0   79.0  2.2
# Rhode Island           57.0   71.0   76.0   69.0   74.0   86.0  2.1
# South Carolina         80.0   79.0   67.0   68.0   63.0   71.0  2.0
# South Dakota           73.0   91.0   77.0   76.0   99.0   89.0  1.8
# Tennessee             100.0  100.0  100.0   93.0  100.0   95.0  2.0
# Texas                  59.0   57.0   65.0   66.0   68.0   73.0  2.7
# Utah                   54.0   55.0   53.0   47.0   53.0   57.0  3.0
# Vermont                66.0   65.0   59.0   72.0   58.0   56.0  2.0
# Virginia               61.0   60.0   61.0   49.0   47.0   69.0  1.9
# Washington             52.0   51.0   54.0   53.0   56.0   51.0  2.2
# West Virginia          91.0   91.0   99.0  100.0  100.0  100.0  2.6
# Wisconsin              70.0   66.0   60.0   63.0   65.0   64.0  2.0
# Wyoming                33.0   45.0   60.0   57.0   60.0   55.0  2.1

# %% [markdown]
# # ready for correlation for 1 kw

# %%
year="2011"
cor = pearsonr(data[year], data["gt"])[0]
cor
# Out:
# -0.12229862727098589

# %%
def getCor(queryMat,type_,year):
    
    if type_ == 'AAP':
        if year == 2011:
            m=matrix[:,0]
            gt_Year_Type = 'data/BRFSS/2011_AA.csv'
        if year == 2012:
            m=matrix[:,1]
            gt_Year_Type = 'data/BRFSS/2012_AA.csv'
        if year == 2013:
            m=matrix[:,2]
            gt_Year_Type = 'data/BRFSS/2013_AA.csv'
        if year == 2014:
            m=matrix[:,3]
            gt_Year_Type = 'data/BRFSS/2014_AA.csv'
        if year == 2015:
            m=matrix[:,4]
            gt_Year_Type = 'data/BRFSS/2015_AA.csv'
        if year == 2016:
            m=matrix[:,5]
            gt_Year_Type = 'data/BRFSS/2016_AA.csv'
        
    if type_ == 'CP':
        if year == 2011:
            m=matrix[:,0]
            gt_Year_Type = 'data/BRFSS/2011.csv'
        if year == 2012:
            m=matrix[:,1]
            gt_Year_Type = 'data/BRFSS/2012.csv'
        if year == 2013:
            m=matrix[:,2]
            gt_Year_Type = 'data/BRFSS/2013.csv'
        if year == 2014:
            m=matrix[:,3]
            gt_Year_Type = 'data/BRFSS/2014.csv'
        if year == 2015:
            m=matrix[:,4]
            gt_Year_Type = 'data/BRFSS/2015.csv'
        if year == 2016:
            m=matrix[:,5]
            gt_Year_Type = 'data/BRFSS/2016.csv'
    
    #kw_list = query
    #kw_list=['kidney']
    #pytrends.build_payload(kw_list, cat=0, timeframe=year, geo='US', gprop='')
    #googleTrend = pytrends.interest_by_region()
    df_gt = pd.read_csv(gt_Year_Type, sep=";")
    df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
    df_gt = df_gt.dropna(subset=['LocationAbbr']) 
    print(df_gt[["LocationAbbr","Data_Value"]])
    
#   googleTrend = outputQueryAPI (query,year)  # GABRIEL API
    #googleTrend = pd.read_csv(query,sep=",")

    g = m
    print(g)
    return
    google_values = [x[0] for x in g.values]
    google_states = []
    st = dict((y,x) for x, y in states.items())
    index = list(g.index)
    google_states = []
    for state in st:
        if state in index:
            google_states.append(st[state])
    d = {'idx': google_values, 'stat': google_states}
    d = pd.DataFrame(data=d)
    df2_gt = df_gt
    df2_gt = df2_gt[df2_gt['LocationAbbr'].isin(google_states)]

    # create a compact ground truth dataframe
    df2_gt = pd.DataFrame(data=list(df2_gt.Data_Value), index=list(df2_gt.LocationAbbr), columns=['value'],
                          dtype=np.float)

    google_df = pd.DataFrame(data=google_values, index=google_states, columns=['value'], dtype=np.float)

    # normalizing
    df2_gt = (df2_gt - df2_gt.mean())/df2_gt.std()
    google_df = (google_df - google_df.mean())/google_df.std()

    # order
    df2_gt = df2_gt.sort_index()
    google_df = google_df.sort_index()
    cor = pearsonr(df2_gt, google_df)[0][0]
    
    
    
    return cor

# %%
getCor(queryMat = matrix,year = 2011,type_= "AAP")
# Out:
#    LocationAbbr  Data_Value
# 0            AL         2.5
# 1            AK         2.5
# 2            AZ         3.4
# 3            AR         2.8
# 4            CA         2.5
# 5            CO         2.2
# 6            CT         1.8
# 7            DE         2.4
# 8            DC         2.7
# 9            FL         3.0
# 10           GA         2.9
# 11           HI         3.2
# 12           ID         2.4
# 13           IL         2.7
# 14           IN         2.0
# 15           IA         1.3
# 16           KS         2.2
# 17           KY         2.4
# 18           LA         2.5
# 19           ME         2.1
# 20           MD         1.8
# 21           MA         1.8
# 22           MI         2.9
# 23           MN         1.6
# 24           MS         2.3
# 25           MO         2.1
# 26           MT         2.4
# 27           NE         2.1
# 28           NV         2.5
# 29           NH         2.4
# 30           NJ         1.9
# 31           NM         2.9
# 32           NY         2.8
# 33           NC         2.1
# 34           ND         1.8
# 35           OH         2.3
# 36           OK         2.9
# 37           OR         2.3
# 38           PA         2.2
# 39           RI         2.1
# 40           SC         2.0
# 41           SD         1.8
# 42           TN         2.0
# 43           TX         2.7
# 44           UT         3.0
# 45           VT         2.0
# 46           VA         1.9
# 47           WA         2.2
# 48           WV         2.6
# 49           WI         2.0
# 50           WY         2.1
# 51           GU         3.2
# 52           PR         2.0
# [  58.   70.   67.    0.   63.   46.   48.   63.   53.   44.   62.   54.
#     0.   55.   63.   50.   57.   74.   62.   72.   78.   61.   63.   63.
#    69.   63.   74.    0.   84.   58.    0.   60.   79.   68.   65.   54.
#    71.   52.   51.   69.   80.   54.   72.    0.   62.   68.   72.  100.
#    56.   51.   54.    0.   45.   48.   63.   91.   38.]
