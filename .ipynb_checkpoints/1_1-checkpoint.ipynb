# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')

# %%
wls = pd.read_csv("kidneyRelatedTerms.csv",sep=".")
wordsList = list(wls[" liver"])
kw_list= []
for i in wordsList:
    kw_list.append(i.strip())
df_gt = pd.read_csv('data/BRFSS/2011_AA.csv', sep=";")


states = df_gt["LocationDesc"][2:53]

# %%
def buildDF(kword):
    k1 =[]
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    
    k1.extend(values)
    #k1 += values
    #print(k1)
   
    print("lunghezza anno2011  ",len(k1))


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    #k1 += values
    #print(k1)


    print("lunghezza anno2012   ",len(k1))

    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2013.  ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2014   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2015   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2016   ",len(k1))


    return k1

# %% [markdown]
# k = np.zeros(shape=(342,len(kw_list)))
# i=0
# for word in kw_list:
#     k[:,i] = buildDF([word])
#     i +=1

# %%
matrix = np.zeros(shape=(51,6))

# %%
def buildDF1(kword):
    badWords =[]
    
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        #print(values)
        matrix[:,0]=(values)
        #k1 += values
        #print(k1)
    except: 
        badWords.append(kword)
 


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,1]=(values)
    except:
        badWords.append(kword)

    #k1 += values
    #print(k1)



    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,2]=(values)
    except:
        badWords.append(kword)
     


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,3]=(values)
    except:
        badWords.append(kword)
        

    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,4]=(values)
    except:
        badWords.append(kword)
      


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,5]=(values)
    except:
        badWords.append(kword)
        

    


    #print(k1)
    #for i in range(len(k1)):
    #    k1[i]= int(k1[i][0])
        #print(int(k[i][0]))
    return matrix

# %% [markdown]
# ## for each word in querylist

# %%
mat=buildDF1([word])
gt_Year_Type = 'data/BRFSS/2011_AA.csv'
data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
df_gt = pd.read_csv(gt_Year_Type, sep=";")
df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
df_gt = df_gt.dropna(subset=['LocationAbbr'])
data["gt"]=df_gt["Data_Value"][:-2].values
# Out:
#  calculating indexes for  ['transplant']

# %%
cor= []
year = [2011,2012,2013,2014,2015,2016]
for y in year:
    cor.append(pearsonr(data[str(y)], data["gt"])[0])
np.mean(cor)
# Out:
# -0.057790295766935756

# %%
# get mean over years

# %%
c=[]
import progressbar
from time import sleep
bar = progressbar.ProgressBar(maxval=20, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
for kw in kw_list:
    mat=buildDF1([kw])
    gt_Year_Type = 'data/BRFSS/2011_AA.csv'
    data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
    df_gt = pd.read_csv(gt_Year_Type, sep=";")
    df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
    df_gt = df_gt.dropna(subset=['LocationAbbr'])
    data["gt"]=df_gt["Data_Value"][:-2].values
    cor= []
    year = [2011,2012,2013,2014,2015,2016]
    bar.update(i+1)
    sleep(0.1)
    for y in year:
        cor.append(pearsonr(data[str(y)], data["gt"])[0])
    c.append(np.mean(cor))
# Out:
#  calculating indexes for  ['transplant']
#  calculating indexes for  ['renal']
#  calculating indexes for  ['dialysis']
#  calculating indexes for  ['transplantation']
#  calculating indexes for  ['hepatic']
#  calculating indexes for  ['giraffe']
#  calculating indexes for  ['bean']
#  calculating indexes for  ['dose']
#  calculating indexes for  ['waist']
#  calculating indexes for  ['rooster']
#  calculating indexes for  ['rim']
#  calculating indexes for  ['college']
#  calculating indexes for  ['yin']
#  calculating indexes for  ['holistic']
#  calculating indexes for  ['rein']
#  calculating indexes for  ['pure']
#  calculating indexes for  ['back']
#  calculating indexes for  ['faculty']
#  calculating indexes for  ['arc']
#  calculating indexes for  ['simple']
#  calculating indexes for  ['narrow']
#  calculating indexes for  ['overall']
#  calculating indexes for  ['Rene']
#  calculating indexes for  ['mere']
#  calculating indexes for  ['purely']
#  calculating indexes for  ['macroeconomics']
#  calculating indexes for  ['total']
#  calculating indexes for  ['straightforward']
#  calculating indexes for  ['rené']
#  calculating indexes for  ['aggregate']
#  calculating indexes for  ['lnt']
#  calculating indexes for  ['macro']
#  calculating indexes for  ['Rhine']
#  calculating indexes for  ['strictly']
#  calculating indexes for  ['pancreas']
#  calculating indexes for  ['kidney disease']
#  calculating indexes for  ['lung']
#  calculating indexes for  ['renal failure']
#  calculating indexes for  ['marrow']
#  calculating indexes for  ['gallbladder']
#  calculating indexes for  ['liver disease']
#  calculating indexes for  ['bowel']
#  calculating indexes for  ['thyroid']
#  calculating indexes for  ['urinary']
#  calculating indexes for  ['intestine']
#  calculating indexes for  ['nephron']
#  calculating indexes for  ['bladder']
#  calculating indexes for  ['renal cortex']
#  calculating indexes for  ['bone marrow']
#  calculating indexes for  ['organs']
#  calculating indexes for  ['renal corpuscle']
#  calculating indexes for  ['antinephritic']
#  calculating indexes for  ['kidney failure']
#  calculating indexes for  ['organ transplant']
#  calculating indexes for  ['cardiomyopathy']
#  calculating indexes for  ['perinephritis']
#  calculating indexes for  ['nephroptosis']
#  calculating indexes for  ['renal vein']
#  calculating indexes for  ['gall bladder']
#  calculating indexes for  ['polycystic kidney disease']
#  calculating indexes for  ['corneas']
#  calculating indexes for  ['corneal graft']
#  calculating indexes for  ['heart valve']
#  calculating indexes for  ['leukemia']
#  calculating indexes for  ['corneal transplant']
#  calculating indexes for  ['malpighian corpuscle']
#  calculating indexes for  ['portal vein']
#  calculating indexes for  ['transfusion']
#  calculating indexes for  ['suprarenal gland']
#  calculating indexes for  ['pancreatic juice']
#  calculating indexes for  ['hepatic duct']
#  calculating indexes for  ['Bojanus Organ']
#  calculating indexes for  ['surgery']
#  calculating indexes for  ['aortic valve']
#  calculating indexes for  ['hepatic portal vein']
#  calculating indexes for  ['nephridium']
#  calculating indexes for  ['prostate']
#  calculating indexes for  ['aplastic anemia']
#  calculating indexes for  ['nephrolith']
#  calculating indexes for  ['pneumogastric']
#  calculating indexes for  ['pulmonary stenosis']
#  calculating indexes for  ['purtenance']
#  calculating indexes for  ['blood transfusion']
#  calculating indexes for  ['aneurysm']
#  calculating indexes for  ['liver cancer']
#  calculating indexes for  ['nephrosis']
#  calculating indexes for  ['brain tumor']
#  calculating indexes for  ['angiosarcoma']
#  calculating indexes for  ['splenization']
#  calculating indexes for  ['heart']
#  calculating indexes for  ['diaphragmatic hernia']
#  calculating indexes for  ['bile duct']
#  calculating indexes for  ['malpighian body']
#  calculating indexes for  ['acute myeloid leukemia']
#  calculating indexes for  ['platelet']
#  calculating indexes for  ['leukodystrophy']
#  calculating indexes for  ['nephritis']
#  calculating indexes for  ['nephrolithic']
#  calculating indexes for  ['pulmonary valve']
#  calculating indexes for  ['urochrome']
#  calculating indexes for  ['respiratory organ']
#  calculating indexes for  ['chemotherapy']
#  calculating indexes for  ['tissue']
#  calculating indexes for  ['cyanopathy']
#  calculating indexes for  ['gallstones']
#  calculating indexes for  ['hydrocephalus']
#  calculating indexes for  ['aortic aneurysm']
#  calculating indexes for  ['chronic renal failure']
#  calculating indexes for  ['cancer']
#  calculating indexes for  ['vital organ']
#  calculating indexes for  ['ovary']
#  calculating indexes for  ['colon']
#  calculating indexes for  ['urogenital system']
#  calculating indexes for  ['valvular heart disease']
#  calculating indexes for  ['pheresis']
#  calculating indexes for  ['lymphoblastic leukemia']
#  calculating indexes for  ['uterus']
#  calculating indexes for  ['myoma']
#  calculating indexes for  ['tumor']
#  calculating indexes for  ['cerebral aneurysm']
#  calculating indexes for  ['common bile duct']
#  calculating indexes for  ['hypovolemic shock']
#  calculating indexes for  ['clotting']
#  calculating indexes for  ['blastoma']
#  calculating indexes for  ['aneurism']
#  calculating indexes for  ['skin grafting']
#  calculating indexes for  ['hemolytic anemia']
#  calculating indexes for  ['islet of langerhans']
#  calculating indexes for  ['pyloric stenosis']
#  calculating indexes for  ['organ donor']
#  calculating indexes for  ['hemangioma']
#  calculating indexes for  ['pancreatic cancer']
#  calculating indexes for  ['coronary artery']
#  calculating indexes for  ['plasmapheresis']
#  calculating indexes for  ['parathyroid gland']
#  calculating indexes for  ['lymph gland']
#  calculating indexes for  ['cataract']
#  calculating indexes for  ['clot buster']
#  calculating indexes for  ['bilestone']
#  calculating indexes for  ['colon cancer']
#  calculating indexes for  ['blood clot']
#  calculating indexes for  ['myocarditis']
#  calculating indexes for  ['blood']
#  calculating indexes for  ['capillary bed']
#  calculating indexes for  ['hyperparathyroidism']
#  calculating indexes for  ['lienal artery']
#  calculating indexes for  ['bladdery']
#  calculating indexes for  ['arterialization']
#  calculating indexes for  ['small intestine']
#  calculating indexes for  ['rheumatic fever']
#  calculating indexes for  ['nephrostome']
#  calculating indexes for  ['chemo']
#  calculating indexes for  ['hiatus hernia']
#  calculating indexes for  ['monopathy']
#  calculating indexes for  ['atresia']
#  calculating indexes for  ['wilms tumour']
#  calculating indexes for  ['coronary bypass']
#  calculating indexes for  ['internal organ']
#  calculating indexes for  ['grafts']
#  calculating indexes for  ['surgical procedure']
#  calculating indexes for  ['hemochromatosis']
#  calculating indexes for  ['nephralgia']
#  calculating indexes for  ['aorta']
#  calculating indexes for  ['skin graft']
#  calculating indexes for  ['hypercalcinuria']
#  calculating indexes for  ['uremia']
#  calculating indexes for  ['cystic fibrosis']
#  calculating indexes for  ['donor']
#  calculating indexes for  ['neurofibromatosis']
#  calculating indexes for  ['dihydrotachysterol']
#  calculating indexes for  ['inmeats']
#  calculating indexes for  ['circle of willis']
#  calculating indexes for  ['serolin']
#  calculating indexes for  ['gastric artery']
#  calculating indexes for  ['physoclist']
#  calculating indexes for  ['achylia']
#  calculating indexes for  ['mesohepar']
#  calculating indexes for  ['hepatization']
#  calculating indexes for  ['bilifuscin']
#  calculating indexes for  ['organ']
#  calculating indexes for  ['hypotrophy']
#  calculating indexes for  ['glandular disease']
#  calculating indexes for  ['chyloderma']
#  calculating indexes for  ['liquid body substance']
#  calculating indexes for  ['erethism']
#  calculating indexes for  ['hypernoea']
#  calculating indexes for  ['vesicouterine']
#  calculating indexes for  ['uropoetic']
#  calculating indexes for  ['cirrhosis']
#  calculating indexes for  ['church music']
#  calculating indexes for  ['nephrotomy']
#  calculating indexes for  ['ovarium']
#  calculating indexes for  ['cystose']
#  calculating indexes for  ['pneumatocele']
#  calculating indexes for  ['hematosis']
#  calculating indexes for  ['ureter']
#  calculating indexes for  ['uroglaucin']
#  calculating indexes for  ['barium meal']
#  calculating indexes for  ['rachischisis']
#  calculating indexes for  ['variety meat']
#  calculating indexes for  ['hyparterial']
#  calculating indexes for  ['lithagogue']
#  calculating indexes for  ['antisplenetic']
#  calculating indexes for  ['cor pulmonale']
#  calculating indexes for  ['hyperinosis']
#  calculating indexes for  ['physostomous']
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-41-3ae111b8b9fb> in <module>()
#       1 c=[]
#       2 for kw in kw_list:
# ----> 3     mat=buildDF1([kw])
#       4     gt_Year_Type = 'data/BRFSS/2011_AA.csv'
#       5     data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
#
# <ipython-input-38-fd1809e5f605> in buildDF1(kword)
#      63         pass
#      64
# ---> 65     pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
#      66     values = []
#      67
#
# ~/anaconda3/lib/python3.6/site-packages/pytrends/request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     106         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     107         # get tokens
# --> 108         self._tokens()
#     109         return
#     110
#
# ~/anaconda3/lib/python3.6/site-packages/pytrends/request.py in _tokens(self)
#     117             method=TrendReq.GET_METHOD,
#     118             params=self.token_payload,
# --> 119             trim_chars=4,
#     120         )['widgets']
#     121
#
# ~/anaconda3/lib/python3.6/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#      86             # is not allowed by Google
#      87             raise exceptions.ResponseError('The request failed: Google returned a '
# ---> 88                                            'response with code {0}.'.format(response.status_code), response=response)
#      89
#      90     def build_payload(self, kw_list, cat=0, timeframe='today 5-y', geo='', gprop=''):
#
# ResponseError: The request failed: Google returned a response with code 429.

# %%
l =pd.DataFrame(index=kw_list[:-4],data=c) ## SBAGLIATO
l

# %%
p=l.loc[l[0]>0.2].values
l.loc[l[0]>0.2].index
# Out:
# Index(['yin', 'holistic', 'arc', 'strictly', 'suprarenal gland',
#        'pancreatic juice', 'aortic valve', 'bile duct', 'malpighian body',
#        'aortic aneurysm', 'urogenital system', 'valvular heart disease',
#        'myoma', 'skin grafting', 'vesicouterine', 'uropoetic', 'nephrotomy'],
#       dtype='object')

# %%
plt.figure(figsize=(13,7))
plt.plot(p, label ="Age Adjusted prevalence 13")

plt.legend(fontsize="small")
plt.xlabel("query term")
plt.ylabel("Cor value ")
plt.title("Correlation")
plt.grid()
#plt.xticks(queries)

plt.show()

# %%
l
# Out:
#                               0
# transplant            -0.057790
# renal                 -0.047712
# dialysis               0.053910
# transplantation       -0.072515
# hepatic               -0.063480
# giraffe                0.024603
# bean                   0.090239
# dose                  -0.008109
# waist                  0.172349
# rooster               -0.026209
# rim                    0.168249
# college                0.162820
# yin                    0.270328
# holistic               0.214047
# rein                   0.095991
# pure                   0.066342
# back                   0.068556
# faculty                0.118724
# arc                    0.289497
# simple                 0.157512
# narrow                 0.064248
# overall                0.133970
# Rene                   0.148211
# mere                   0.085547
# purely                 0.067618
# macroeconomics         0.173266
# total                  0.129587
# straightforward        0.117746
# rené                   0.059221
# aggregate              0.154855
# ...                         ...
# achylia               -0.150792
# mesohepar             -0.150792
# hepatization          -0.150792
# bilifuscin            -0.150792
# organ                  0.081296
# hypotrophy             0.032067
# glandular disease      0.032067
# chyloderma             0.032067
# liquid body substance  0.032067
# erethism              -0.112925
# hypernoea             -0.112925
# vesicouterine          0.349639
# uropoetic              0.349639
# cirrhosis             -0.035461
# church music           0.037690
# nephrotomy             0.349639
# ovarium                0.046075
# cystose                0.046075
# pneumatocele          -0.061644
# hematosis              0.023570
# ureter                -0.074095
# uroglaucin            -0.074095
# barium meal           -0.142041
# rachischisis           0.087292
# variety meat           0.087292
# hyparterial            0.087292
# lithagogue             0.087292
# antisplenetic          0.087292
# cor pulmonale         -0.031377
# hyperinosis           -0.031377
#
# [205 rows x 1 columns]
