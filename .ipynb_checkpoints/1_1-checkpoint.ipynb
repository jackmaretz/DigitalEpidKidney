# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')

# %%
wls = pd.read_csv("kidneyRelatedTerms.csv",sep=".")
wordsList = list(wls[" liver"])
kw_list= []
for i in wordsList:
    kw_list.append(i.strip())
df_gt = pd.read_csv('data/BRFSS/2011_AA.csv', sep=";")


states = df_gt["LocationDesc"][2:53]

# %%
def buildDF(kword):
    k1 =[]
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    
    k1.extend(values)
    #k1 += values
    #print(k1)
   
    print("lunghezza anno2011  ",len(k1))


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    #k1 += values
    #print(k1)


    print("lunghezza anno2012   ",len(k1))

    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2013.  ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2014   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2015   ",len(k1))


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []


    x = pytrends.interest_by_region()
    for s in states:
        if s not in x.index:
            values.append(0)
        else: values.append(int(x.loc[s].values))
    k1.extend(values)
    print("lunghezza anno2016   ",len(k1))


    return k1

# %% [markdown]
# k = np.zeros(shape=(342,len(kw_list)))
# i=0
# for word in kw_list:
#     k[:,i] = buildDF([word])
#     i +=1

# %%
matrix = np.zeros(shape=(51,6))

# %%
def buildDF1(kword):
    k1 =[]
    print( " calculating indexes for " ,kword)
    pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
    values = []
    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        #print(values)
        matrix[:,0]=(values)
        #k1 += values
        #print(k1)
    except: 
        pass 


    
    pytrends.build_payload(kword, cat=0, timeframe='2012-01-01 2012-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,1]=(values)
    except: 
        pass
    #k1 += values
    #print(k1)



    pytrends.build_payload(kword, cat=0, timeframe='2013-01-01 2013-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,2]=(values)
    except: 
        pass


    pytrends.build_payload(kword, cat=0, timeframe='2014-01-01 2014-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,3]=(values)
    except: 
        pass

    pytrends.build_payload(kword, cat=0, timeframe='2015-01-01 2015-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,4]=(values)
    except: 
        pass


    pytrends.build_payload(kword, cat=0, timeframe='2016-01-01 2016-12-31', geo='US', gprop='')
    values = []

    try:
        x = pytrends.interest_by_region()
        for s in states:
            if s not in x.index:
                values.append(0)
            else: values.append(int(x.loc[s].values))
        matrix[:,5]=(values)
    except: 
        pass

    


    #print(k1)
    #for i in range(len(k1)):
    #    k1[i]= int(k1[i][0])
        #print(int(k[i][0]))
    return matrix

# %% [markdown]
# ## for each word in querylist

# %%
mat=buildDF1([word])
gt_Year_Type = 'data/BRFSS/2011_AA.csv'
data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
df_gt = pd.read_csv(gt_Year_Type, sep=";")
df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
df_gt = df_gt.dropna(subset=['LocationAbbr'])
data["gt"]=df_gt["Data_Value"][:-2].values
# Out:
#  calculating indexes for  ['rat']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0

# %%
cor= []
year = [2011,2012,2013,2014,2015,2016]
for y in year:
    cor.append(pearsonr(data[str(y)], data["gt"])[0])
np.mean(cor)
# Out:
# 0.065114153510014747

# %%
# get mean over years

# %%
c=[]
for kw in kw_list:
    mat=buildDF1([kw])
    gt_Year_Type = 'data/BRFSS/2011_AA.csv'
    data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
    df_gt = pd.read_csv(gt_Year_Type, sep=";")
    df_gt = df_gt[np.logical_not(pd.to_numeric(df_gt.LocationAbbr, errors='coerce').notnull())]
    df_gt = df_gt.dropna(subset=['LocationAbbr'])
    data["gt"]=df_gt["Data_Value"][:-2].values
    cor= []
    year = [2011,2012,2013,2014,2015,2016]
    for y in year:
        cor.append(pearsonr(data[str(y)], data["gt"])[0])
    c.append(np.mean(cor))
# Out:
#  calculating indexes for  ['transplant']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['renal']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['dialysis']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['transplantation']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['hepatic']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['giraffe']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['bean']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['dose']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['waist']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['rooster']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['rim']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['college']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['yin']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['holistic']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['rein']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['pure']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['back']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['faculty']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['arc']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['simple']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['narrow']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['overall']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['Rene']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['mere']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['purely']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['macroeconomics']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['total']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['straightforward']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['rené']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['aggregate']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['lnt']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['macro']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['Rhine']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['strictly']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['pancreas']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['kidney disease']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['lung']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['renal failure']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['marrow']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['gallbladder']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['liver disease']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['bowel']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['thyroid']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['urinary']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['intestine']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['nephron']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['bladder']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['renal cortex']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['bone marrow']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['organs']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['renal corpuscle']
# lunghezza anno2011   0
# lunghezza anno2012    0
# lunghezza anno2013.   0
# lunghezza anno2014    0
# lunghezza anno2015    0
# lunghezza anno2016    0
#  calculating indexes for  ['antinephritic']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3ae111b8b9fb> in <module>()
#       1 c=[]
#       2 for kw in kw_list:
# ----> 3     mat=buildDF1([kw])
#       4     gt_Year_Type = 'data/BRFSS/2011_AA.csv'
#       5     data = pd.DataFrame(data=mat, index=states,columns=["2011","2012","2013","2014","2015","2016"])
#
# <ipython-input-15-d426b16827c7> in buildDF1(kword)
#       4     pytrends.build_payload(kword, cat=0, timeframe='2011-01-01 2011-12-31', geo='US', gprop='')
#       5     values = []
# ----> 6     x = pytrends.interest_by_region()
#       7     for s in states:
#       8         if s not in x.index:
#
# ~/anaconda3/lib/python3.6/site-packages/pytrends/request.py in interest_by_region(self, resolution)
#     206         df = pd.DataFrame(req_json['default']['geoMapData'])
#     207         # rename the column with the search keyword
# --> 208         df = df[['geoName', 'value']].set_index(['geoName']).sort_index()
#     209         # split list columns into seperate ones, remove brackets and split on comma
#     210         result_df = df['value'].apply(lambda x: pd.Series(str(x).replace('[', '').replace(']', '').split(',')))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['geoName' 'value'] not in index"

# %%
kw_list
# Out:
# ['transplant',
#  'renal',
#  'dialysis',
#  'transplantation',
#  'hepatic',
#  'giraffe',
#  'bean',
#  'dose',
#  'waist',
#  'rooster',
#  'rim',
#  'college',
#  'yin',
#  'holistic',
#  'rein',
#  'pure',
#  'back',
#  'faculty',
#  'arc',
#  'simple',
#  'narrow',
#  'overall',
#  'Rene',
#  'mere',
#  'purely',
#  'macroeconomics',
#  'total',
#  'straightforward',
#  'rené',
#  'aggregate',
#  'lnt',
#  'macro',
#  'Rhine',
#  'strictly',
#  'pancreas',
#  'kidney disease',
#  'lung',
#  'renal failure',
#  'marrow',
#  'gallbladder',
#  'liver disease',
#  'bowel',
#  'thyroid',
#  'urinary',
#  'intestine',
#  'nephron',
#  'bladder',
#  'renal cortex',
#  'bone marrow',
#  'organs',
#  'renal corpuscle',
#  'antinephritic',
#  'kidney failure',
#  'organ transplant',
#  'cardiomyopathy',
#  'perinephritis',
#  'nephroptosis',
#  'renal vein',
#  'gall bladder',
#  'polycystic kidney disease',
#  'corneas',
#  'corneal graft',
#  'heart valve',
#  'leukemia',
#  'corneal transplant',
#  'malpighian corpuscle',
#  'portal vein',
#  'transfusion',
#  'suprarenal gland',
#  'pancreatic juice',
#  'hepatic duct',
#  'Bojanus Organ',
#  'surgery',
#  'aortic valve',
#  'hepatic portal vein',
#  'nephridium',
#  'prostate',
#  'aplastic anemia',
#  'nephrolith',
#  'pneumogastric',
#  'pulmonary stenosis',
#  'purtenance',
#  'blood transfusion',
#  'aneurysm',
#  'liver cancer',
#  'nephrosis',
#  'brain tumor',
#  'angiosarcoma',
#  'splenization',
#  'heart',
#  'diaphragmatic hernia',
#  'bile duct',
#  'malpighian body',
#  'acute myeloid leukemia',
#  'platelet',
#  'leukodystrophy',
#  'nephritis',
#  'nephrolithic',
#  'pulmonary valve',
#  'urochrome',
#  'respiratory organ',
#  'chemotherapy',
#  'tissue',
#  'cyanopathy',
#  'gallstones',
#  'hydrocephalus',
#  'aortic aneurysm',
#  'chronic renal failure',
#  'cancer',
#  'vital organ',
#  'ovary',
#  'colon',
#  'urogenital system',
#  'valvular heart disease',
#  'pheresis',
#  'lymphoblastic leukemia',
#  'uterus',
#  'myoma',
#  'tumor',
#  'cerebral aneurysm',
#  'common bile duct',
#  'hypovolemic shock',
#  'clotting',
#  'blastoma',
#  'aneurism',
#  'skin grafting',
#  'hemolytic anemia',
#  'islet of langerhans',
#  'pyloric stenosis',
#  'organ donor',
#  'hemangioma',
#  'pancreatic cancer',
#  'coronary artery',
#  'plasmapheresis',
#  'parathyroid gland',
#  'lymph gland',
#  'cataract',
#  'clot buster',
#  'bilestone',
#  'colon cancer',
#  'blood clot',
#  'myocarditis',
#  'blood',
#  'capillary bed',
#  'hyperparathyroidism',
#  'lienal artery',
#  'bladdery',
#  'arterialization',
#  'small intestine',
#  'rheumatic fever',
#  'nephrostome',
#  'chemo',
#  'hiatus hernia',
#  'monopathy',
#  'atresia',
#  'wilms tumour',
#  'coronary bypass',
#  'internal organ',
#  'grafts',
#  'surgical procedure',
#  'hemochromatosis',
#  'nephralgia',
#  'aorta',
#  'skin graft',
#  'hypercalcinuria',
#  'uremia',
#  'cystic fibrosis',
#  'donor',
#  'neurofibromatosis',
#  'dihydrotachysterol',
#  'inmeats',
#  'circle of willis',
#  'serolin',
#  'gastric artery',
#  'physoclist',
#  'achylia',
#  'mesohepar',
#  'hepatization',
#  'bilifuscin',
#  'organ',
#  'hypotrophy',
#  'glandular disease',
#  'chyloderma',
#  'liquid body substance',
#  'erethism',
#  'hypernoea',
#  'vesicouterine',
#  'uropoetic',
#  'cirrhosis',
#  'church music',
#  'nephrotomy',
#  'ovarium',
#  'cystose',
#  'pneumatocele',
#  'hematosis',
#  'ureter',
#  'uroglaucin',
#  'barium meal',
#  'rachischisis',
#  'variety meat',
#  'hyparterial',
#  'lithagogue',
#  'antisplenetic',
#  'cor pulmonale',
#  'hyperinosis',
#  'physostomous',
#  'bleareye',
#  'gastrosplenic',
#  'antialbumid']

# %%
len(c)
# Out:
# 51
