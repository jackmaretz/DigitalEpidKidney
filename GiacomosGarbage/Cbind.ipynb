# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ExportCSV.csv",sep=";")#2016 210
df = df.append(pd.read_csv("ExportCSV-2.csv",sep=";"))
df = df.append(pd.read_csv("ExportCSV-3.csv",sep=";"))
df = df.append(pd.read_csv("ExportCSV-4.csv",sep=";"))
df = df.append(pd.read_csv("ExportCSV-5.csv",sep=";"))
df = df.append(pd.read_csv("ExportCSV-6.csv",sep=";"))#2011 66


df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a7ebebec65c7> in <module>()
# ----> 1 df = pd.read_csv("ExportCSV.csv",sep=";")#2016 210
#       2 df = df.append(pd.read_csv("ExportCSV-2.csv",sep=";"))
#       3 df = df.append(pd.read_csv("ExportCSV-3.csv",sep=";"))
#       4 df = df.append(pd.read_csv("ExportCSV-4.csv",sep=";"))
#       5 df = df.append(pd.read_csv("ExportCSV-5.csv",sep=";"))
#
# ...

# %%
df = pd.read_csv("ExportCSV.csv",sep=";")
#print(np.logical_not(pd.to_numeric(df.LocationAbbr, errors='coerce').notnull()))
#df.LocationAbbr

df= df[np.logical_not(pd.to_numeric(df.LocationAbbr, errors='coerce').notnull())]

df.isnull().sum()
df = df.dropna(subset=['LocationAbbr'])   #Drop only if NaN in specific column (as asked in the question)

df.isnull().sum()

df.LocationAbbr
# Out:
# 0      US
# 1      UW
# 2      AL
# 5      AK
# 7      AZ
# 9      AR
# 12     CA
# 19     CO
# 22     CT
# 24     DE
# 25     DC
# 27     FL
# 40     GA
# 43     HI
# 44     ID
# 46     IL
# 48     IN
# 51     IA
# 56     KS
# 60     KY
# 63     LA
# 66     ME
# 68     MD
# 74     MA
# 79     MI
# 83     MN
# 88     MS
# 90     MO
# 92     MT
# 94     NE
# 100    NV
# 102    NH
# 106    NJ
# 110    NM
# 112    NY
# 123    NC
# 126    ND
# 131    OH
# 137    OK
# 140    OR
# 143    PA
# 148    RI
# 150    SC
# 157    SD
# 160    TN
# 166    TX
# 176    UT
# 181    VT
# 183    VA
# 186    WA
# 189    WV
# 192    WI
# 194    WY
# 195    GU
# 196    PR
# 198    VI
# Name: LocationAbbr, dtype: object

# %%
len(df.LocationAbbr.dropna())
df = df.dropna(subset=['LocationAbbr'])   #Drop only if NaN in specific column (as asked in the question)
df.isnull().sum()
#df.shape
# Out:
# ID                             0
# Year                           0
# LocationAbbr                   0
# LocationDesc                   0
# Class                          0
# Topic                          0
# Indicator                      0
# Response                       0
# DataSource                     0
# Data_Value_Unit                0
# Data_Value_Type                0
# Data_Value                     0
# Data_Value_Footnote_Symbol    56
# Data_Value_Footnote           56
# Low_Confidence_Limit           2
# High_Confidence_Limit          2
# Sample_Size                    0
# Stratification                 0
# StratificationType             0
# IndicatorId                    0
# LocationOrder                  0
# ParentStateDisplayOrder        0
# FootnoteType                  56
# FootNoteSymbol                56
# FootnoteText                  56
# URL                           56
# DatasourceAbbr                56
# Agency                        56
# dtype: int64

# %%
df2 = pd.read_csv("ExportCSV-2.csv",sep=";")
#df2.isnull().values.any()
# Out:
# (66, 28)

# %%
print(len(df2.LocationAbbr.dropna()))
#df2.isnull().sum()
#df2 = df2.dropna()
df2.dropna(subset=['LocationAbbr'])   #Drop only if NaN in specific column (as asked in the question)
df2 = df2.dropna(subset=['LocationAbbr'])
print(len(df2.dropna(subset=['LocationAbbr'])))
df2.shape
# Out:
# 55
# 55
# (55, 28)

# %%
#pd.concat([df1['c'], df2['c']], axis=1, keys=['df1', 'df2'])

#pd.concat([df["LocationAbbr"], df2["LocationAbbr"]], axis=1, keys=['df1', 'df2'])

# %%
set(df.LocationAbbr).difference(set(df2.LocationAbbr))
# Out:
# {'VI'}

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(df2.LocationAbbr,df2.Data_Value)
plt.title("DF2, 2015,")
plt.show()

# %%
gk2015 = pd.read_csv("GoogleKidney2015.csv",sep=",")#2015

# %%
gk2015.head()[1:]
# Out:
#               Category: All categories
# West Virginia                      100
# Kentucky                            92
# Mississippi                         91
# Alabama                             90

# %%
gk2015.columns
# Out:
# Index(['Category: All categories'], dtype='object')

# %%
g = (gk2015[1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-26ed83b4df6d> in <module>()
# ----> 1 g = int(gk2015[1:])
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(g,height=100,color="red")
plt.title("DF2, 2015,")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-230-277b07516ffd> in <module>()
#       1 plt.figure(figsize=(20,10))
#       2 plt.grid()
# ----> 3 plt.bar(g,height=100,color="red")
#       4 plt.title("DF2, 2015,")
#       5 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(*args, **kwargs)
#    2625                       mplDeprecation)
#    2626     try:
# -> 2627         ret = ax.bar(*args, **kwargs)
#    2628     finally:
#    2629         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
# ...

# %%
g = g.convert_objects(convert_numeric=True)
g =g.sort_index()
# Out:
# /Users/giacomomaretto/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
g["Category: All categories"].dtype
# Out:
# dtype('int64')

# %%
plt.figure(figsize=(20,10))
g.plot.bar()

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(df2.LocationAbbr,df2.Data_Value)
plt.title("DF2, 2015,")
plt.show()

# %%
l =[x[0] for x in g.values]

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(g.index,l)
plt.title("Google, 2015,")
plt.show()

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
s= []
i=0
for state in g.index:
    if list(states.values())[i] == state:
        s.append(list(states.keys())[i])
    i += 1

# %%
st = dict((y,x) for x,y in states.items())
s= []
for state in st:
    s.append(st[state])
print(len(s),len(l))
len(set(l).difference(set(s)))
# Out:
# 57 51
# 24

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.bar(s,l)
plt.title("Google, 2015,")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-d4dd540a92a1> in <module>()
#       1 plt.figure(figsize=(20,10))
#       2 plt.grid()
# ----> 3 plt.bar(s,l)
#       4 plt.title("Google, 2015,")
#       5 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(*args, **kwargs)
#    2625                       mplDeprecation)
#    2626     try:
# -> 2627         ret = ax.bar(*args, **kwargs)
#    2628     finally:
#    2629         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ...
